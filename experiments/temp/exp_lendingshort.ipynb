# %%
from anchor import utils
from anchor import anchor_tabular
import pandas as pd
import sklearn.ensemble
import numpy as np
from anchor import anchor_tabular
import os

# %%
dataset_folder = '../../../datasets/'
def filter_fn(data):
    to_remove = ['Does not meet the credit policy. Status:Charged Off',
        'Does not meet the credit policy. Status:Fully Paid',
        'In Grace Period', '-999', 'Current']
    for x in to_remove:
        data = data[data[:, 16] != x]
    return data
bad_statuses = set(["Late (16-30 days)", "Late (31-120 days)", "Default", "Charged Off"])
transformations = {
    16:  lambda x: np.array([y in bad_statuses for y in x]).astype(int),
    19:  lambda x: np.array([len(y) for y in x]).astype(int),
    6:  lambda x: np.array([y.strip('%') if y else -1 for y in x]).astype(float),
    35:  lambda x: np.array([y.strip('%') if y else -1 for y in x]).astype(float),
}
#features_to_use = [2, 12, 13, 19, 29, 35, 51, 52, 109]
features_to_use = [2, 12, 13, 19, 29] #, 35, 51, 52, 109]
categorical_features = [12] #, 109]
dataset = utils.load_csv_dataset(
    os.path.join(dataset_folder, 'lendingclub/LoanStats3a_securev1.csv'),
    16, ',',  features_to_use=features_to_use,
    feature_transformations=transformations, fill_na='-999',
    categorical_features=categorical_features, discretize=True,
    filter_fn=filter_fn, balance=True)
dataset.class_names = ['Good Loan', 'Bad Loan']
print(dataset.train[0])
# Out:
# [1. 0. 3. 0. 0.]

# %%
import sys
sys.path.append(sys.path[0] + '/../..')

import arg_explainer as ae
import dataset_manager
import testbench
import utils

nb_rows = 100
dm = dataset_manager.DatasetManager(dataset, classifier=None, nb_rows=nb_rows)
print(dm.space_size())
explainer = ae.ArgTabularExplainer(dm, 'lendingshort_' + str(nb_rows), compute=True, output_path='../../saves')
tb = testbench.Testbench(dm)

# tb.explore_full_dataset(16)
# tb.explore_neighborhoods(16)
# Out:
# Train 0.94
# Test 0.5220458553791887
# 960
# lendingshort_100
# Generating arguments
# len  1 : 0 ,  0
# 18 potential arg checked ( 0 not minimal)
# len  2 : 6 ,  15
# 123 potential arg checked ( 0 not minimal)
# len  3 : 49 ,  55
# 251 potential arg checked ( 86 not minimal)
# len  4 : 13 ,  5
# 60 potential arg checked ( 252 not minimal)
# len  5 : 0 ,  0
# 0 potential arg checked ( 84 not minimal)
# Total number of arguments:  143
# Saving to  ../../saves\lendingshort_100_minimals.df

# %%
dm = dataset_manager.DatasetManager(dataset, classifier=None, nb_rows=None)
c = dm.get_classifier()

for nb_rows in utils.make_slices(dm.get_nb_rows(), 10):
    dm = dataset_manager.DatasetManager(dataset, classifier=c, nb_rows=nb_rows)
    explainer = ae.ArgTabularExplainer(dm, 'lendingshort_' + str(nb_rows), compute=True, output_path='../../saves', verbose=False)
    G = explainer.build_attack_graph(compute=True, display_graph=False)
    print('edges per node:', np.mean([len(G.edges(n)) for n in G.nodes()]))
    print('nodes:', len(G.nodes()))
    print('edges:', len(G.edges()))
# Out:
# Train 0.6363836824696802
# Test 0.5687830687830688
# lendingshort_907
# Total number of arguments:  317
# Saving to  ../../saves\lendingshort_907_minimals.df
# edges per node: 2.5615141955835963
# nodes: 317
# edges: 406
# lendingshort_1814
# Total number of arguments:  343
# Saving to  ../../saves\lendingshort_1814_minimals.df
# edges per node: 1.7959183673469388
# nodes: 343
# edges: 308
# lendingshort_2721
# Total number of arguments:  366
# Saving to  ../../saves\lendingshort_2721_minimals.df
# edges per node: 1.7322404371584699
# nodes: 366
# edges: 317
# lendingshort_3628
# Total number of arguments:  373
# Saving to  ../../saves\lendingshort_3628_minimals.df
# edges per node: 1.5764075067024128
# nodes: 373
# edges: 294
# lendingshort_4535
# Total number of arguments:  377
# Saving to  ../../saves\lendingshort_4535_minimals.df
# edges per node: 1.389920424403183
# nodes: 377
# edges: 262
# lendingshort_5442
# Total number of arguments:  387
# Saving to  ../../saves\lendingshort_5442_minimals.df
# edges per node: 1.1369509043927648
# nodes: 387
# edges: 220
# lendingshort_6349
# Total number of arguments:  392
# Saving to  ../../saves\lendingshort_6349_minimals.df
# edges per node: 1.066326530612245
# nodes: 392
# edges: 209
# lendingshort_7256
# Total number of arguments:  393
# Saving to  ../../saves\lendingshort_7256_minimals.df
# edges per node: 0.9770992366412213
# nodes: 393
# edges: 192
# lendingshort_8163
# Total number of arguments:  398
# Saving to  ../../saves\lendingshort_8163_minimals.df
# edges per node: 0.9195979899497487
# nodes: 398
# edges: 183
# lendingshort_9070
# Total number of arguments:  396
# Saving to  ../../saves\lendingshort_9070_minimals.df
# edges per node: 0.8888888888888888
# nodes: 396
# edges: 176

# %%
explainer.af_analysis(remove=['20', '50', '100', '432', '864', '1296', '1728', '2160', '2592', '3024', '3456', '3888', '4320', '4752', '5184', '5616', '6048', '6480', '6912', '13824', '20736', '27648', '34560', '41472', '48384', '55296', '62208', '69120', '76032', '82944', '89856', '96768', '103680', '110592'])
# Out:
# [308, 317, 294, 262, 220, 209, 192, 183, 176, 406]
# (907, 1814, 2721, 3628, 4535, 5442, 6349, 7256, 8163, 9070) (317, 343, 366, 373, 377, 387, 392, 393, 398, 396)
# (9070, 8163, 7256, 6349, 5442, 4535, 3628, 2721, 1814, 907) (0.7727272727272727, 0.7613065326633166, 0.7455470737913485, 0.7091836734693877, 0.6925064599483204, 0.6206896551724138, 0.5737265415549597, 0.540983606557377, 0.49271137026239065, 0.3028391167192429)

# %%
G = explainer.build_attack_graph(compute=True, display_graph=False)
print('edges per node:', np.mean([len(G.edges(n)) for n in G.nodes()]))

explainer.export_graph('asp', '../../saves')
print(len(G.nodes()))
# Out:
# lendingshort_50
# edges per node: 11.669724770642201
# 109

# %%
from typing import OrderedDict
import networkx as nx
from sklearn import preprocessing
import random
from numba import njit

le = preprocessing.LabelEncoder()


def generate_full_dataset():
    instance = OrderedDict.fromkeys(explainer.dataset.columns)
    full_dataset = []

    def gen_rec(instance, columns, col_index, full_dataset):
        inst_ = instance.copy()
        if col_index == len(columns) - 1:
            for f in explainer.features_p_col[columns[col_index]]:
                inst_[columns[col_index]] = explainer.feature_names[f][len(columns[col_index])+1:] #.strip(columns[col_index] + '_')
                full_dataset.append(list(inst_.values()))
        else:
            inst_ = instance.copy()
            for f in explainer.features_p_col[columns[col_index]]:
                inst_[columns[col_index]] = explainer.feature_names[f][len(columns[col_index])+1:] #.strip(columns[col_index] + '_')
                gen_rec(inst_, columns, col_index + 1, full_dataset)

    gen_rec(instance, list(instance.keys()), 0, full_dataset)
    return full_dataset

def instance2encoded(instance, dataset):
    encoded = []
    for col in dataset.categorical_features:
        encoded.append(dataset.categorical_names[col].index(instance[col]))
    return np.array(encoded)

def explore_full_dataset(nb_steps):
    full_dataset = generate_full_dataset()
    y_plus = [c.predict(instance2encoded(i_, dataset).reshape(1,-1))[0] for i_ in full_dataset]
    #train_data_plus = train_data = pd.DataFrame(transformed_data[:nb_vals] + transformed_data_plus, columns=dataset.feature_names)
    
    random.seed(1)
    indices = list(range(len(full_dataset)))
    random.shuffle(indices)
    full_dataset_shuff = [full_dataset[i] for i in indices] 
    y_plus_shuff = [y_plus[i] for i in indices]

    print(np.unique(np.array(y_plus_shuff)))
    
    step_len = len(full_dataset)//nb_steps
    steps = [i*step_len for i in range(1, nb_steps)]
    steps.append(len(full_dataset))
    for nb_vals in steps:
        dataset_t = full_dataset_shuff[:nb_vals]
        y_t = y_plus_shuff[:nb_vals]
        print('total length', len(dataset_t), len(y_t))
        train_data_plus = pd.DataFrame(dataset_t, columns=dataset.feature_names)

        explainer = ae.ArgTabularExplainer(c, train_data_plus, y_t, 'lendingshort_' + str(nb_vals) + '_synth', compute=True, output_path='../../saves')

        G = explainer.build_attack_graph(compute=True, display_graph=False)
        print('total args:', len(G.nodes()))
        print('edges per node:', np.mean([len(G.edges(n)) for n in G.nodes()]))

explore_full_dataset(16)
# Out:
# [0 1]
# total length 432 432
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 44 ,  32
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 925 ,  863
# 4470 potential arg checked ( 752 not minimal)
# len  5 : 131 ,  196
# 1295 potential arg checked ( 5169 not minimal)
# len  6 : 0 ,  0
# 93 potential arg checked ( 2711 not minimal)
# len  7 : 0 ,  0
# 0 potential arg checked ( 432 not minimal)
# Saving to  ../../saves\lendingshort_432_synth_minimals.df
# lendingshort_432_synth
# total args: 2191
# edges per node: 67.92332268370608
# total length 864 864
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 3 ,  4
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 586 ,  546
# 5470 potential arg checked ( 90 not minimal)
# len  5 : 858 ,  959
# 4543 potential arg checked ( 4898 not minimal)
# len  6 : 10 ,  10
# 348 potential arg checked ( 4793 not minimal)
# len  7 : 0 ,  0
# 0 potential arg checked ( 864 not minimal)
# Saving to  ../../saves\lendingshort_864_synth_minimals.df
# lendingshort_864_synth
# total args: 2976
# edges per node: 40.293010752688176
# total length 1296 1296
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  2
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 270 ,  282
# 5557 potential arg checked ( 26 not minimal)
# len  5 : 1461 ,  1400
# 7477 potential arg checked ( 3273 not minimal)
# len  6 : 66 ,  62
# 858 potential arg checked ( 6221 not minimal)
# len  7 : 0 ,  0
# 0 potential arg checked ( 1296 not minimal)
# Saving to  ../../saves\lendingshort_1296_synth_minimals.df
# lendingshort_1296_synth
# total args: 3543
# edges per node: 27.99435506632797
# total length 1728 1728
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  2
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 154 ,  142
# 5558 potential arg checked ( 26 not minimal)
# len  5 : 1530 ,  1523
# 9197 potential arg checked ( 2202 not minimal)
# len  6 : 216 ,  233
# 1634 potential arg checked ( 7083 not minimal)
# len  7 : 0 ,  0
# 0 potential arg checked ( 1728 not minimal)
# Saving to  ../../saves\lendingshort_1728_synth_minimals.df
# lendingshort_1728_synth
# total args: 3800
# edges per node: 19.95
# total length 2160 2160
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  1
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 97 ,  92
# 5571 potential arg checked ( 13 not minimal)
# len  5 : 1346 ,  1456
# 10176 potential arg checked ( 1481 not minimal)
# len  6 : 472 ,  421
# 2595 potential arg checked ( 7477 not minimal)
# len  7 : 0 ,  0
# 0 potential arg checked ( 2160 not minimal)
# Saving to  ../../saves\lendingshort_2160_synth_minimals.df
# lendingshort_2160_synth
# total args: 3885
# edges per node: 14.566280566280566
# total length 2592 2592
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 63 ,  64
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 1179 ,  1268
# 10746 potential arg checked ( 998 not minimal)
# len  6 : 698 ,  664
# 3696 potential arg checked ( 7368 not minimal)
# len  7 : 1 ,  1
# 2 potential arg checked ( 2590 not minimal)
# Saving to  ../../saves\lendingshort_2592_synth_minimals.df
# lendingshort_2592_synth
# total args: 3938
# edges per node: 10.484002031488066
# total length 3024 3024
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 52 ,  41
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 957 ,  1104
# 11026 potential arg checked ( 765 not minimal)
# len  6 : 979 ,  899
# 4802 potential arg checked ( 7125 not minimal)
# len  7 : 3 ,  4
# 7 potential arg checked ( 3017 not minimal)
# Saving to  ../../saves\lendingshort_3024_synth_minimals.df
# lendingshort_3024_synth
# total args: 4039
# edges per node: 7.8712552612032685
# total length 3456 3456
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 39 ,  36
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 811 ,  922
# 11173 potential arg checked ( 629 not minimal)
# len  6 : 1206 ,  1079
# 5855 potential arg checked ( 6713 not minimal)
# len  7 : 5 ,  7
# 12 potential arg checked ( 3444 not minimal)
# Saving to  ../../saves\lendingshort_3456_synth_minimals.df
# lendingshort_3456_synth
# total args: 4105
# edges per node: 6.03020706455542
# total length 3888 3888
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 32 ,  28
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 677 ,  821
# 11285 potential arg checked ( 523 not minimal)
# len  6 : 1307 ,  1183
# 6699 potential arg checked ( 6320 not minimal)
# len  7 : 8 ,  13
# 21 potential arg checked ( 3867 not minimal)
# Saving to  ../../saves\lendingshort_3888_synth_minimals.df
# lendingshort_3888_synth
# total args: 4069
# edges per node: 4.858196116982059
# total length 4320 4320
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 30 ,  19
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 586 ,  743
# 11377 potential arg checked ( 431 not minimal)
# len  6 : 1393 ,  1263
# 7495 potential arg checked ( 5840 not minimal)
# len  7 : 20 ,  22
# 42 potential arg checked ( 4278 not minimal)
# Saving to  ../../saves\lendingshort_4320_synth_minimals.df
# lendingshort_4320_synth
# total args: 4076
# edges per node: 3.8895976447497547
# total length 4752 4752
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 28 ,  16
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 502 ,  678
# 11423 potential arg checked ( 385 not minimal)
# len  6 : 1407 ,  1251
# 8097 potential arg checked ( 5468 not minimal)
# len  7 : 35 ,  33
# 68 potential arg checked ( 4684 not minimal)
# Saving to  ../../saves\lendingshort_4752_synth_minimals.df
# lendingshort_4752_synth
# total args: 3950
# edges per node: 3.093164556962025
# total length 5184 5184
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 20 ,  13
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 468 ,  615
# 11513 potential arg checked ( 295 not minimal)
# len  6 : 1351 ,  1232
# 8651 potential arg checked ( 5054 not minimal)
# len  7 : 64 ,  48
# 112 potential arg checked ( 5072 not minimal)
# Saving to  ../../saves\lendingshort_5184_synth_minimals.df
# lendingshort_5184_synth
# total args: 3811
# edges per node: 2.2928365258462344
# total length 5616 5616
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 17 ,  11
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 428 ,  557
# 11549 potential arg checked ( 259 not minimal)
# len  6 : 1289 ,  1180
# 9101 potential arg checked ( 4680 not minimal)
# len  7 : 96 ,  78
# 174 potential arg checked ( 5442 not minimal)
# Saving to  ../../saves\lendingshort_5616_synth_minimals.df
# lendingshort_5616_synth
# total args: 3656
# edges per node: 1.599562363238512
# total length 6048 6048
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 17 ,  11
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 374 ,  487
# 11549 potential arg checked ( 259 not minimal)
# len  6 : 1252 ,  1156
# 9547 potential arg checked ( 4264 not minimal)
# len  7 : 136 ,  112
# 248 potential arg checked ( 5800 not minimal)
# Saving to  ../../saves\lendingshort_6048_synth_minimals.df
# lendingshort_6048_synth
# total args: 3545
# edges per node: 0.9337094499294781
# total length 6480 6480
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 16 ,  10
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 326 ,  444
# 11566 potential arg checked ( 242 not minimal)
# len  6 : 1168 ,  1124
# 9900 potential arg checked ( 3924 not minimal)
# len  7 : 189 ,  146
# 335 potential arg checked ( 6145 not minimal)
# Saving to  ../../saves\lendingshort_6480_synth_minimals.df
# lendingshort_6480_synth
# total args: 3423
# edges per node: 0.42068361086765993
# total length 6912 6912
# Generating arguments
# len  1 : 0 ,  0
# 25 potential arg checked ( 0 not minimal)
# len  2 : 0 ,  0
# 267 potential arg checked ( 0 not minimal)
# len  3 : 0 ,  0
# 1579 potential arg checked ( 0 not minimal)
# len  4 : 15 ,  9
# 5584 potential arg checked ( 0 not minimal)
# len  5 : 289 ,  406
# 11583 potential arg checked ( 225 not minimal)
# len  6 : 1090 ,  1080
# 10215 potential arg checked ( 3609 not minimal)
# len  7 : 253 ,  186
# 439 potential arg checked ( 6473 not minimal)
# Saving to  ../../saves\lendingshort_6912_synth_minimals.df
# lendingshort_6912_synth
# total args: 3328
# edges per node: 0.0

# %%
explainer.af_analysis(remove=["lending_"])
# Out:
# [5875, 10224, 0, 49592, 2178707, 37905, 1466414, 28295, 20643, 1020326, 15896, 698858, 12377, 9884, 494714, 7927, 74410, 6109, 358672, 4369, 266994, 2924, 1655, 198046, 720, 146475, 0, 106213, 73181, 59956, 46060, 25236]
# (100, 432, 864, 1296, 1728, 2160, 2592, 3024, 3456, 3888, 4320, 4752, 5184, 5616, 6048, 6480, 6912, 13824, 20736, 27648, 34560, 41472, 48384, 55296, 62208, 69120, 76032, 82944, 89856, 96768, 103680, 110592) (321, 2191, 2976, 3543, 3800, 3885, 3938, 4039, 4105, 4069, 4076, 3950, 3811, 3656, 3545, 3423, 3328, 40873, 43517, 43637, 42544, 41781, 40581, 39143, 37655, 36079, 34368, 32532, 30397, 28463, 26542, 24909)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\henro\ws\argumentation\argument-based-explainer\experiments\ijcai\exp_lendingshort.ipynb Cell 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/henro/ws/argumentation/argument-based-explainer/experiments/ijcai/exp_lendingshort.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> explainer.af_analysis(remove=["lending_"])
#
# File c:\Users\henro\ws\argumentation\argument-based-explainer\experiments\ijcai/../..\arg_explainer.py:280, in ArgTabularExplainer.af_analysis(self, remove)
#     278 arg_lengths = [0] * (len(self.dataset.columns) + 1)
#     279 for arg in minimals[0]:
# --> 280     arg_lengths[len(arg)] += 1
#     281 for arg in minimals[1]:
#     282     arg_lengths[len(arg)] += 1
#
# IndexError: list index out of range

# %%
#ext_gen = explainer.extension_generator_from_graph()
ext_gen = explainer.extension_generator_from_sat(file='../../saves/lendingshort_50_sat.txt')
#max_covi_ext = explainer.make_selection('max_covi_incl', ext_gen)
max_covi_ext = explainer.make_selection('max_card', ext_gen)
res = explainer.apply_inference(max_covi_ext, 'universal')
#print(res)

explainer.display_explanations(verbose=True)
# Out:
# Using pre-processed file...
# Reading ../../saves/lendingshort_50_sat_preprocessed.txt
# Time for selection:  490.22679829597473
# Len max_cov_exts:  1
# id: 0 coverage: 10 Arg 1/3: frozenset({'inq_last_6mths_inq_last_6mths <= 0.00', 'annual_inc_annual_inc > 82000.00', 'home_ownership_MORTGAGE'})
# id: 1 coverage: 0 Arg 1/0: None
# id: 2 coverage: 0 Arg 1/0: None
# id: 3 coverage: 0 Arg 1/0: None
# id: 4 coverage: 0 Arg 1/0: None
# id: 5 coverage: 0 Arg 1/0: None
# id: 6 coverage: 0 Arg 1/0: None
# id: 7 coverage: 9 Arg 1/5: frozenset({'inq_last_6mths_inq_last_6mths <= 0.00', 'desc_4.00 < desc <= 145.00', 'loan_amnt_loan_amnt > 15000.00'})
# id: 8 coverage: 4 Arg 1/4: frozenset({'annual_inc_59000.00 < annual_inc <= 82000.00', 'desc_desc > 392.00'})
# id: 9 coverage: 0 Arg 1/0: None
# id: 10 coverage: 5 Arg 1/1: frozenset({'inq_last_6mths_0.00 < inq_last_6mths <= 1.00', 'desc_desc > 392.00'})
# id: 11 coverage: 5 Arg 1/2: frozenset({'inq_last_6mths_0.00 < inq_last_6mths <= 1.00', 'desc_desc > 392.00'})
# id: 12 coverage: 1 Arg 1/2: frozenset({'home_ownership_RENT', 'desc_desc <= 4.00', 'loan_amnt_5400.00 < loan_amnt <= 10000.00'})
# id: 13 coverage: 0 Arg 1/0: None
# id: 14 coverage: 2 Arg 1/3: frozenset({'loan_amnt_loan_amnt <= 5400.00', 'home_ownership_RENT', 'desc_4.00 < desc <= 145.00'})
# id: 15 coverage: 3 Arg 1/3: frozenset({'annual_inc_59000.00 < annual_inc <= 82000.00', 'desc_desc > 392.00'})
# id: 16 coverage: 0 Arg 1/0: None
# id: 17 coverage: 0 Arg 1/0: None
# id: 18 coverage: 10 Arg 1/3: frozenset({'inq_last_6mths_inq_last_6mths <= 0.00', 'annual_inc_annual_inc > 82000.00', 'home_ownership_MORTGAGE'})
# id: 19 coverage: 0 Arg 1/0: None
# id: 20 coverage: 10 Arg 1/4: frozenset({'inq_last_6mths_inq_last_6mths <= 0.00', 'annual_inc_annual_inc > 82000.00', 'home_ownership_MORTGAGE'})
# id: 21 coverage: 2 Arg 1/4: frozenset({'loan_amnt_loan_amnt <= 5400.00', 'home_ownership_MORTGAGE', 'desc_desc > 392.00'})
# id: 22 coverage: 0 Arg 1/0: None
# id: 23 coverage: 0 Arg 1/0: None
# id: 24 coverage: 5 Arg 1/1: frozenset({'inq_last_6mths_0.00 < inq_last_6mths <= 1.00', 'desc_desc > 392.00'})
# id: 25 coverage: 1 Arg 1/4: frozenset({'inq_last_6mths_0.00 < inq_last_6mths <= 1.00', 'annual_inc_40057.66 < annual_inc <= 59000.00', 'desc_145.00 < desc <= 392.00'})
# id: 26 coverage: 0 Arg 1/0: None
# id: 27 coverage: 7 Arg 1/5: frozenset({'annual_inc_59000.00 < annual_inc <= 82000.00', 'loan_amnt_loan_amnt > 15000.00', 'inq_last_6mths_0.00 < inq_last_6mths <= 1.00'})
# id: 28 coverage: 1 Arg 1/7: frozenset({'loan_amnt_10000.00 < loan_amnt <= 15000.00', 'home_ownership_RENT', 'desc_145.00 < desc <= 392.00'})
# id: 29 coverage: 7 Arg 1/5: frozenset({'annual_inc_annual_inc > 82000.00', 'home_ownership_MORTGAGE', 'desc_desc <= 4.00'})
# id: 30 coverage: 0 Arg 1/0: None
# id: 31 coverage: 0 Arg 1/0: None
# id: 32 coverage: 0 Arg 1/0: None
# id: 33 coverage: 9 Arg 1/4: frozenset({'inq_last_6mths_inq_last_6mths <= 0.00', 'annual_inc_annual_inc > 82000.00', 'home_ownership_MORTGAGE'})
# id: 34 coverage: 0 Arg 1/0: None
# id: 35 coverage: 3 Arg 1/5: frozenset({'home_ownership_RENT', 'annual_inc_annual_inc > 82000.00', 'loan_amnt_5400.00 < loan_amnt <= 10000.00'})
# id: 36 coverage: 0 Arg 1/0: None
# id: 37 coverage: 2 Arg 1/5: frozenset({'home_ownership_OWN', 'desc_desc > 392.00'})
# id: 38 coverage: 10 Arg 1/3: frozenset({'inq_last_6mths_inq_last_6mths <= 0.00', 'annual_inc_annual_inc > 82000.00', 'home_ownership_MORTGAGE'})
# id: 39 coverage: 9 Arg 1/4: frozenset({'inq_last_6mths_inq_last_6mths <= 0.00', 'annual_inc_annual_inc > 82000.00', 'home_ownership_MORTGAGE'})
# id: 40 coverage: 0 Arg 1/0: None
# id: 41 coverage: 8 Arg 1/4: frozenset({'inq_last_6mths_inq_last_6mths <= 0.00', 'annual_inc_annual_inc > 82000.00', 'desc_145.00 < desc <= 392.00'})
# id: 42 coverage: 0 Arg 1/0: None
# id: 43 coverage: 10 Arg 1/5: frozenset({'annual_inc_annual_inc > 82000.00', 'desc_desc > 392.00'})
# id: 44 coverage: 5 Arg 1/5: frozenset({'annual_inc_annual_inc > 82000.00', 'home_ownership_MORTGAGE', 'desc_desc <= 4.00'})
# id: 45 coverage: 0 Arg 1/0: None
# id: 46 coverage: 0 Arg 1/0: None
# id: 47 coverage: 0 Arg 1/0: None
# id: 48 coverage: 0 Arg 1/0: None
# id: 49 coverage: 0 Arg 1/0: None
# success =  0.48 (empty= 26 )
